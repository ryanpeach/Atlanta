# %%
import matplotlib
matplotlib.use('Agg')
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

import pandas as pd
import matplotlib.pyplot as plt
from scipy import misc
import numpy as np

# %matplotlib notebook

# %% [markdown]
# # Import Data

# %%
data2017 = pd.read_csv("./assets/COBRA-YTD2017.csv")
data2017.head()
# Out:
#    MI_PRINX  offense_id    rpt_date  occur_date occur_time   poss_date  \
# 0   7366952   162680163  02/25/2017  09/24/2016   01:00:00  09/24/2016
# 1   7370443   163090763  01/02/2017  11/04/2016   23:00:00  01/02/2017
# 2   7371856   163282668  04/20/2017  11/23/2016   19:00:00  11/23/2016
# 3   7373785   163522791  01/02/2017  12/18/2016   01:00:00  12/18/2016
# 4   7373854   163532016  01/19/2017  12/18/2016   16:46:00  12/18/2016
#
#   poss_time  beat apt_office_prefix apt_office_num    ...    dispo_code  \
# 0  01:00:00   204               NaN            NaN    ...           NaN
# 1  23:00:00   306               NaN            NaN    ...           NaN
# 2  20:00:00   211               NaN            NaN    ...            10
# 3  01:30:00   303               NaN            NaN    ...           NaN
# 4  16:50:00   506               NaN            NaN    ...           NaN
#
#    MaxOfnum_victims Shift Avg Day  loc_type           UC2 Literal  \
# ...

# %%
data2016 = pd.read_csv("./assets/COBRADATA2016.csv")
data2016.head()
# Out:
#    MI_PRINX  offense_id    rpt_date  occur_date occur_time   poss_date  \
# 0   5637549   150102493  01/10/2016  01/10/2016   22:00:00  01/10/2016
# 1   5641270   150611492  03/01/2016  02/25/2016   12:00:00  02/29/2016
# 2   5648012   151471800  05/26/2016  05/26/2016   08:30:00  05/26/2016
# 3   5659772   152792664  01/13/2016  10/06/2015   20:00:00  10/06/2015
# 4   5664938   153412960  01/13/2016  12/07/2015   21:00:00  12/07/2015
#
#   poss_time  beat apt_office_prefix apt_office_num    ...    dispo_code  \
# 0  22:00:00   511               NaN            NaN    ...           NaN
# 1  19:00:00   412               NaN            NaN    ...           NaN
# 2  13:00:00   206               NaN            NaN    ...           NaN
# 3  20:25:00   210               NaN            NaN    ...           NaN
# 4  21:05:00   208               NaN            NaN    ...           NaN
#
#    MaxOfnum_victims Shift Avg Day  loc_type           UC2 Literal  \
# ...

# %% [markdown]
# Do they have all the same columns?

# %%
out = len(data2016.columns)==len(data2017.columns) # Verify that they are the same length in terms of columns
if out:
    for i in data2016.columns: # go through all columns in 2016
        if i not in data2017.columns: # and check that they are in 2017
            out = False
            break
print(out)
# Out:
# True

# %% [markdown]
# Ok, great. Now lets concatenate them.

# %%
data = pd.concat([data2016, data2017])
print(len(data)==len(data2016)+len(data2017)) # Verify they are indeed the proper new length
data.head()
# Out:
# True
#    MI_PRINX  offense_id    rpt_date  occur_date occur_time   poss_date  \
# 0   5637549   150102493  01/10/2016  01/10/2016   22:00:00  01/10/2016
# 1   5641270   150611492  03/01/2016  02/25/2016   12:00:00  02/29/2016
# 2   5648012   151471800  05/26/2016  05/26/2016   08:30:00  05/26/2016
# 3   5659772   152792664  01/13/2016  10/06/2015   20:00:00  10/06/2015
# 4   5664938   153412960  01/13/2016  12/07/2015   21:00:00  12/07/2015
#
#   poss_time  beat apt_office_prefix apt_office_num    ...    dispo_code  \
# 0  22:00:00   511               NaN            NaN    ...           NaN
# 1  19:00:00   412               NaN            NaN    ...           NaN
# 2  13:00:00   206               NaN            NaN    ...           NaN
# 3  20:25:00   210               NaN            NaN    ...           NaN
# 4  21:05:00   208               NaN            NaN    ...           NaN
#
#    MaxOfnum_victims Shift Avg Day  loc_type           UC2 Literal  \
# ...

# %% [markdown]
# # Import Image
# Now I will import my atlanta image with the corners at the coordinates P1 and P2.

# %%
ATL = misc.imread("./assets/atl.png")
P1 = (-84.43748, 33.8111)
P2 = (-84.33586, 33.7032)
KYS = (-84.38812, 33.77724)
min_x, min_y, max_x, max_y = min(P1[0],P2[0]), min(P1[1],P2[1]), max(P1[0],P2[0]), max(P1[1],P2[1])
extent = min_x, max_x, min_y, max_y
fig = plt.figure()
ax = fig.add_subplot(1,1,1) 
ax.imshow(ATL, extent=extent)
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.set_title("Atlata, Ga")
print(min_x, min_y, max_x, max_y)
# Out:
# <img src="data:image/png;base64,..." width="640">
# -84.43748 33.7032 -84.33586 33.8111

# %% [markdown]
# # Filter Data
# To only those items which are located on the map.

# %%
print(min(data['x']), min(data['y']))
print(max(data['x']), max(data['y']))
print(min(P1[0],P2[0]), min(P1[1],P2[1]))
print(max(P1[0],P2[0]), max(P1[1],P2[1]))
data_map = data[data['x']>min(P1[0],P2[0])]
data_map = data_map[data_map['x']<max(P1[0],P2[0])]
data_map = data_map[data_map['y']>min(P1[1],P2[1])]
data_map = data_map[data_map['y']<max(P1[1],P2[1])]
data_map.head()
# Out:
# -84.5505 33.62522
# -84.29042 33.88424
# -84.43748 33.7032
# -84.33586 33.8111
#     MI_PRINX  offense_id    rpt_date  occur_date occur_time   poss_date  \
# 0    5637549   150102493  01/10/2016  01/10/2016   22:00:00  01/10/2016
# 1    5641270   150611492  03/01/2016  02/25/2016   12:00:00  02/29/2016
# 2    5648012   151471800  05/26/2016  05/26/2016   08:30:00  05/26/2016
# 7    5666797   160010061  01/01/2016  01/01/2016   00:03:00  01/01/2016
# 10   5666800   160010159  01/01/2016  12/31/2015   23:00:00  01/01/2016
#
#    poss_time  beat apt_office_prefix apt_office_num    ...    dispo_code  \
# 0   22:00:00   511               NaN            NaN    ...           NaN
# 1   19:00:00   412               NaN            NaN    ...           NaN
# 2   13:00:00   206               NaN            NaN    ...           NaN
# 7   00:09:00   403               NaN            NaN    ...           NaN
# 10  00:30:00   305               NaN            NaN    ...           NaN
#
# ...

# %% [markdown]
# # Plot
# Lets try a couple of kinds of plots.

# %%
x = np.array(data_map['x']).astype("float")
y = np.array(data_map['y']).astype("float")

# %% [markdown]
# A Scatter plot will probably be too dense to really discern any meaning.

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1) 
ax.scatter(x,y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# So instead lets try a histogram.

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1) 
ax.hist2d(x, y, bins=100,range=[[min_x, max_x], [min_y, max_y]], cmap="Reds")
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.set_title("Atlata, Ga")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Now let's try merging the images with the map.

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
extent = min_x, max_x, min_y, max_y
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.set_title("Atlata, Ga")

@interact(alpha=(0.,1.), bins=(10,100,1))    
def overlay(alpha, bins):
    ax.imshow(ATL, extent=extent)
    hist = ax.hist2d(x, y, bins=int(bins), range=[[min_x, max_x], [min_y, max_y]], alpha=alpha, cmap="Reds")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Walkscore
# Now im interested in the walkscore of a place.

# %%
from walkscore.api import TransitScore
import pickle
apiKey='ffd1c56f9abcf84872116b4cc2dfcf31'

def maybe_load():
    try:
        with open('transit_score.pickle', 'rb') as handle:
            out = pickle.load(handle)
            print("Loaded!")
            return out
    except:
        print("Did not load.")
        return {}
transit_score = maybe_load()
# Out:
# Loaded!

# %%
def transitscore(x,y,verbose=False):
    if (x,y) in transit_score:
        return transit_score[(x,y)]["transit_score"]
    else:
        if verbose:
            print("API Call...")

        # reference https://www.walkscore.com/professional/public-transit-api.php
        params = {
            'lat': str(y),
            'lon': str(x),
            'city': 'Atlanta',
            'state': 'GA'
        }
        
        dat = TransitScore(apiKey).makeRequest('score', params)
        transit_score[(x,y)] = dat
        return dat["transit_score"]
    
transitscore(min_x+(max_x-min_x)/10/2, min_y)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-19-30342b170836> in <module>()
#      18         return dat["transit_score"]
#      19
# ---> 20 transitscore(min_x+(max_x-min_x)/10/2, min_y)
#
# <ipython-input-19-30342b170836> in transitscore(x, y, verbose)
#      14         }
#      15
# ---> 16         dat = TransitScore(apiKey).makeRequest('score', params)
#      17         transit_score[(x,y)] = dat
#      18         return dat["transit_score"]
#
# /usr/local/lib/python3.4/dist-packages/walkscore_api_binding-0.2.3-py3.4.egg/walkscore/api.py in makeRequest(self, call_name, params)
#     168
#     169         if responseStatusCode != 200:
# --> 170             raise InvalidApiResponseException(message="API response error", raw=jsonResp, status_code=responseStatusCode)
#     171
#     172         # jsonify response
#
# ...

# %% [markdown]
# ## Plotting

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
extent = min_x, max_x, min_y, max_y
ax.set_xlabel("Longitude")
ax.set_ylabel("Latitude")
ax.set_title("Atlata, Ga")

@interact_manual(alpha=(0.,1.), xbins=(2,20,1), ybins=(2,20,1))    
def overlay(alpha, xbins, ybins):
    ax.imshow(ATL, extent=extent)
    bins = xbins*ybins
    W = np.zeros((int(ybins),int(xbins)))
    for i, j, x, y in ((i,j,x,y) for i, x in enumerate(np.linspace(min_x, max_x, xbins)) for j, y in enumerate(np.linspace(max_y,min_y,ybins))):
        W[j,i] = transitscore(x,y)
        
    ax.imshow(W, extent=extent, alpha=alpha)
    
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="NaN">

# %% [markdown]
# ## Save to CSV

# %%
transit_data = pd.DataFrame.from_dict(transit_score, orient="index")
transit_data.to_csv("./transit_data.csv")

# %%
import pickle
with open('transit_score.pickle', 'wb') as handle:
    pickle.dump(transit_score, handle, protocol=pickle.HIGHEST_PROTOCOL)

# Verify    
with open('transit_score.pickle', 'rb') as handle:
    temp = pickle.load(handle)
print("Upper level verify: ", transit_score==temp)
print("Inner verify: ", all((transit_score[k]==temp[k] for k in transit_score)))
# Out:
# Upper level verify:  True
# Inner verify:  True

# %% [markdown]
# # Combined Histogram

# %%
# The Crime Data
cx = np.array(data_map['x']).astype("float")
cy = np.array(data_map['y']).astype("float")

@interact_manual(alpha=(0.,1.), xbins=(2,20,1), ybins=(2,20,1), wc=(0.,3.), wt=(0.,3.), wd=(0.,3.))    
def overlay(alpha, xbins, ybins, wc=1, wt=1, wd=0):
    fig = plt.figure()
    ax = fig.add_subplot(1,1,1)
    extent = min_x, max_x, min_y, max_y
    ax.set_xlabel("Longitude")
    ax.set_ylabel("Latitude")
    img1 = ax.imshow(ATL, extent=extent)
    
    # The transitscore
    T = np.zeros((int(ybins),int(xbins)))
    for i, j, x, y in ((i,j,x,y) for i, x in enumerate(np.linspace(min_x, max_x, xbins)) for j, y in enumerate(np.linspace(max_y,min_y,ybins))):
        T[j,i] = transitscore(x,y)
    
    # The Crime Data
    C, _, _ = np.histogram2d(cx, cy, bins=(xbins,ybins), range=[[min_x, max_x], [min_y, max_y]])
    
    # Distance
    X, Y = np.meshgrid(np.linspace(min_x, max_x, xbins), np.linspace(max_y,min_y,ybins), indexing='xy')
    D = np.sqrt((X-KYS[0])**2. + (Y-KYS[1])**2)
    
    # linear combination of data
    linear  = wt*((T-np.mean(T))/np.std(T))  # Transit score is a positive feature
    linear -= wc*((C-np.mean(C))/np.std(C))  # Crime is a negative feature
    linear -= wd*((D-np.mean(D))/np.std(D))  # Distance is a negative feature
    linear /= np.std(linear)
    img2 = ax.imshow(linear, extent=extent, alpha=alpha)
    fig.colorbar(img2, ax=ax)
    ax.set_title("Atlata, Ga.\nCrime: {}%, Transit: {}%, Distance: {}%".format(wc*100, wt*100, wd*100))
    
    
plt.show()
